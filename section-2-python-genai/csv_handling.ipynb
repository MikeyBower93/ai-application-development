# %%
import pandas as pd
df = pd.read_csv('model_logs.csv')

# %%
df.head()
# Out:
#          Date                                        Prompt  \
# 0  2023-01-01  Generate a creative story about space travel
# 1  2023-01-02        Write a sci-fi short story set in 2050
# 2  2023-01-03   Write a poem about the future of technology
# 3  2023-01-04     Explain quantum computing in simple terms
# 4  2023-01-05     Explain quantum computing in simple terms
#
#    Response Time (ms)  Tokens Generated
# 0                  62               287
# 1                  45               361
# 2                  33               221
# 3                  53               290
# 4                  75               392

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                100 non-null    str
#  1   Prompt              100 non-null    str
#  2   Response Time (ms)  100 non-null    int64
#  3   Tokens Generated    100 non-null    int64
# dtypes: int64(2), str(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#        Response Time (ms)  Tokens Generated
# count          100.000000        100.000000
# mean            66.650000        342.930000
# std             21.114108         90.095264
# min             30.000000        203.000000
# 25%             47.500000        274.750000
# 50%             70.000000        324.500000
# 75%             86.000000        427.000000
# max             99.000000        500.000000

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date                  datetime64[us]
# Prompt                           str
# Response Time (ms)             int64
# Tokens Generated               int64
# dtype: object

# %%
df = pd.read_csv('model_logs.csv', parse_dates=['Date'])
df.dtypes
# Out:
# Date                  datetime64[us]
# Prompt                           str
# Response Time (ms)             int64
# Tokens Generated               int64
# dtype: object

# %%
mask = df['Response Time (ms)'] > 50
slow_responses = df[mask]

# %%
slow_responses
# Out:
#          Date                                          Prompt  \
# 0  2023-01-01    Generate a creative story about space travel
# 3  2023-01-04       Explain quantum computing in simple terms
# 4  2023-01-05       Explain quantum computing in simple terms
# 5  2023-01-06  Generate marketing copy for a new tech product
# 6  2023-01-07          Write a sci-fi short story set in 2050
# ..        ...                                             ...
# 93 2023-04-04       Explain quantum computing in simple terms
# 95 2023-04-06       Explain quantum computing in simple terms
# 96 2023-04-07          Write a sci-fi short story set in 2050
# 98 2023-04-09  Generate marketing copy for a new tech product
# 99 2023-04-10   Create a recipe using plant-based ingredients
#
#     Response Time (ms)  Tokens Generated
# 0                   62               287
# 3                   53               290
# 4                   75               392
# 5                   61               250
# 6                   87               370
# ..                 ...               ...
# 93                  97               325
# 95                  61               304
# 96                  57               238
# 98                  77               296
# 99                  55               306
#
# [73 rows x 4 columns]

# %%
slow_responses.to_csv('slow_reponses.csv', index=False)

# %% [markdown]
# # Exporting to Excel

# %%
pip install openpyxl -q
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df.to_excel('data.xlsx', index=False)

# %% [markdown]
# # Exporting to Json

# %%
df.to_json('data.json', orient='columns')
# Out:
# /var/folders/73/crr8bntx5hx4dq01cd4mm69m0000gp/T/ipykernel_57703/3769419714.py:1: Pandas4Warning: The default 'epoch' date format is deprecated and will be removed in a future version, please use 'iso' date format instead.
#   df.to_json('data.json', orient='columns')

# %% [markdown]
# # Exporting to SQL

# %%
import sqlite3
conn = sqlite3.connect('chat_data.db')

# %%
df.to_sql('chat_data.db', conn, if_exists='replace', index=False)
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.to_sql('chat_data.db', conn, if_exists='replace', index=False)
#       2 conn.close()
#
# File ~/dev/ai-application-development/section-2-python-genai/genai/lib/python3.14/site-packages/pandas/core/generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2820 """
#    2821 Write records stored in a DataFrame to a SQL database.
#    2822
#    (...)   3048 3
#    3049 """  # noqa: E501
#    3050 from pandas.io import sql
# -> 3052 return sql.to_sql(
#    3053     self,
#    3054     name,
#    3055     con,
#    3056     schema=schema,
#    3057     if_exists=if_exists,
#    3058     index=index,
#    3059     index_label=index_label,
#    3060     chunksize=chunksize,
#    3061     dtype=dtype,
#    3062     method=method,
#    3063 )
#
# File ~/dev/ai-application-development/section-2-python-genai/genai/lib/python3.14/site-packages/pandas/io/sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836     raise NotImplementedError(
#     837         "'frame' argument should be either a Series or a DataFrame"
#     838     )
#     840 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 841     return pandas_sql.to_sql(
#     842         frame,
#     843         name,
#     844         if_exists=if_exists,
#     845         index=index,
#     846         index_label=index_label,
#     847         schema=schema,
#     848         chunksize=chunksize,
#     849         dtype=dtype,
#     850         method=method,
#     851         engine=engine,
#     852         **engine_kwargs,
#     853     )
#
# File ~/dev/ai-application-development/section-2-python-genai/genai/lib/python3.14/site-packages/pandas/io/sql.py:2879, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2868             raise ValueError(f"{col} ({my_type}) not a string")
#    2870 table = SQLiteTable(
#    2871     name,
#    2872     self,
#    (...)   2877     dtype=dtype,
#    2878 )
# -> 2879 table.create()
#    2880 return table.insert(chunksize, method)
#
# File ~/dev/ai-application-development/section-2-python-genai/genai/lib/python3.14/site-packages/pandas/io/sql.py:986, in SQLTable.create(self)
#     985 def create(self) -> None:
# --> 986     if self.exists():
#     987         if self.if_exists == "fail":
#     988             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/dev/ai-application-development/section-2-python-genai/genai/lib/python3.14/site-packages/pandas/io/sql.py:972, in SQLTable.exists(self)
#     971 def exists(self):
# --> 972     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/dev/ai-application-development/section-2-python-genai/genai/lib/python3.14/site-packages/pandas/io/sql.py:2894, in SQLiteDatabase.has_table(self, name, schema)
#    2883 wld = "?"
#    2884 query = f"""
#    2885 SELECT
#    2886     name
#    (...)   2891     AND name={wld};
#    2892 """
# -> 2894 return len(self.execute(query, [name]).fetchall()) > 0
#
# File ~/dev/ai-application-development/section-2-python-genai/genai/lib/python3.14/site-packages/pandas/io/sql.py:2700, in SQLiteDatabase.execute(self, sql, params)
#    2698     raise TypeError("Query must be a string unless using sqlalchemy.")
#    2699 args = [] if params is None else [params]
# -> 2700 cur = self.con.cursor()
#    2701 try:
#    2702     cur.execute(sql, *args)
#
# ProgrammingError: Cannot operate on a closed database.

# %% [markdown]
# # Exporting to YAML

# %%
import yaml
data_dict = df.to_dict(orient='records')

# %%
data_dict
# Out:
# [{'Date': Timestamp('2023-01-01 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 62,
#   'Tokens Generated': 287},
#  {'Date': Timestamp('2023-01-02 00:00:00'),
#   'Prompt': 'Write a sci-fi short story set in 2050',
#   'Response Time (ms)': 45,
#   'Tokens Generated': 361},
#  {'Date': Timestamp('2023-01-03 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 33,
#   'Tokens Generated': 221},
#  {'Date': Timestamp('2023-01-04 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 53,
#   'Tokens Generated': 290},
#  {'Date': Timestamp('2023-01-05 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 75,
#   'Tokens Generated': 392},
#  {'Date': Timestamp('2023-01-06 00:00:00'),
#   'Prompt': 'Generate marketing copy for a new tech product',
#   'Response Time (ms)': 61,
#   'Tokens Generated': 250},
#  {'Date': Timestamp('2023-01-07 00:00:00'),
#   'Prompt': 'Write a sci-fi short story set in 2050',
#   'Response Time (ms)': 87,
#   'Tokens Generated': 370},
#  {'Date': Timestamp('2023-01-08 00:00:00'),
#   'Prompt': 'Describe the impact of AI on healthcare',
#   'Response Time (ms)': 36,
#   'Tokens Generated': 373},
#  {'Date': Timestamp('2023-01-09 00:00:00'),
#   'Prompt': 'Generate marketing copy for a new tech product',
#   'Response Time (ms)': 96,
#   'Tokens Generated': 427},
#  {'Date': Timestamp('2023-01-10 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 37,
#   'Tokens Generated': 457},
#  {'Date': Timestamp('2023-01-11 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 98,
#   'Tokens Generated': 230},
#  {'Date': Timestamp('2023-01-12 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 76,
#   'Tokens Generated': 317},
#  {'Date': Timestamp('2023-01-13 00:00:00'),
#   'Prompt': 'Write a sci-fi short story set in 2050',
#   'Response Time (ms)': 61,
#   'Tokens Generated': 307},
#  {'Date': Timestamp('2023-01-14 00:00:00'),
#   'Prompt': 'Create a recipe using plant-based ingredients',
#   'Response Time (ms)': 98,
#   'Tokens Generated': 257},
#  {'Date': Timestamp('2023-01-15 00:00:00'),
#   'Prompt': 'Write a sci-fi short story set in 2050',
#   'Response Time (ms)': 52,
#   'Tokens Generated': 204},
#  {'Date': Timestamp('2023-01-16 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 81,
#   'Tokens Generated': 486},
#  {'Date': Timestamp('2023-01-17 00:00:00'),
#   'Prompt': 'Generate marketing copy for a new tech product',
#   'Response Time (ms)': 91,
#   'Tokens Generated': 225},
#  {'Date': Timestamp('2023-01-18 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 61,
#   'Tokens Generated': 484},
#  {'Date': Timestamp('2023-01-19 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 78,
#   'Tokens Generated': 242},
#  {'Date': Timestamp('2023-01-20 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 80,
#   'Tokens Generated': 458},
#  {'Date': Timestamp('2023-01-21 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 36,
#   'Tokens Generated': 390},
#  {'Date': Timestamp('2023-01-22 00:00:00'),
#   'Prompt': 'Create a recipe using plant-based ingredients',
#   'Response Time (ms)': 69,
#   'Tokens Generated': 373},
#  {'Date': Timestamp('2023-01-23 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 94,
#   'Tokens Generated': 210},
#  {'Date': Timestamp('2023-01-24 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 53,
#   'Tokens Generated': 301},
#  {'Date': Timestamp('2023-01-25 00:00:00'),
#   'Prompt': 'Describe the impact of AI on healthcare',
#   'Response Time (ms)': 97,
#   'Tokens Generated': 271},
#  {'Date': Timestamp('2023-01-26 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 31,
#   'Tokens Generated': 349},
#  {'Date': Timestamp('2023-01-27 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 67,
#   'Tokens Generated': 314},
#  {'Date': Timestamp('2023-01-28 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 37,
#   'Tokens Generated': 346},
#  {'Date': Timestamp('2023-01-29 00:00:00'),
#   'Prompt': 'Create a recipe using plant-based ingredients',
#   'Response Time (ms)': 97,
#   'Tokens Generated': 257},
#  {'Date': Timestamp('2023-01-30 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 64,
#   'Tokens Generated': 455},
#  {'Date': Timestamp('2023-01-31 00:00:00'),
#   'Prompt': 'Describe the impact of AI on healthcare',
#   'Response Time (ms)': 40,
#   'Tokens Generated': 472},
#  {'Date': Timestamp('2023-02-01 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 42,
#   'Tokens Generated': 265},
#  {'Date': Timestamp('2023-02-02 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 30,
#   'Tokens Generated': 480},
#  {'Date': Timestamp('2023-02-03 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 97,
#   'Tokens Generated': 283},
#  {'Date': Timestamp('2023-02-04 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 42,
#   'Tokens Generated': 231},
#  {'Date': Timestamp('2023-02-05 00:00:00'),
#   'Prompt': 'Summarize the latest research on climate change',
#   'Response Time (ms)': 64,
#   'Tokens Generated': 205},
#  {'Date': Timestamp('2023-02-06 00:00:00'),
#   'Prompt': 'Summarize the latest research on climate change',
#   'Response Time (ms)': 94,
#   'Tokens Generated': 324},
#  {'Date': Timestamp('2023-02-07 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 70,
#   'Tokens Generated': 306},
#  {'Date': Timestamp('2023-02-08 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 31,
#   'Tokens Generated': 339},
#  {'Date': Timestamp('2023-02-09 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 33,
#   'Tokens Generated': 286},
#  {'Date': Timestamp('2023-02-10 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 77,
#   'Tokens Generated': 450},
#  {'Date': Timestamp('2023-02-11 00:00:00'),
#   'Prompt': 'Describe the impact of AI on healthcare',
#   'Response Time (ms)': 99,
#   'Tokens Generated': 437},
#  {'Date': Timestamp('2023-02-12 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 41,
#   'Tokens Generated': 499},
#  {'Date': Timestamp('2023-02-13 00:00:00'),
#   'Prompt': 'Describe the impact of AI on healthcare',
#   'Response Time (ms)': 92,
#   'Tokens Generated': 362},
#  {'Date': Timestamp('2023-02-14 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 52,
#   'Tokens Generated': 300},
#  {'Date': Timestamp('2023-02-15 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 72,
#   'Tokens Generated': 385},
#  {'Date': Timestamp('2023-02-16 00:00:00'),
#   'Prompt': 'Describe the impact of AI on healthcare',
#   'Response Time (ms)': 73,
#   'Tokens Generated': 302},
#  {'Date': Timestamp('2023-02-17 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 44,
#   'Tokens Generated': 204},
#  {'Date': Timestamp('2023-02-18 00:00:00'),
#   'Prompt': 'Summarize the latest research on climate change',
#   'Response Time (ms)': 77,
#   'Tokens Generated': 236},
#  {'Date': Timestamp('2023-02-19 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 46,
#   'Tokens Generated': 318},
#  {'Date': Timestamp('2023-02-20 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 81,
#   'Tokens Generated': 368},
#  {'Date': Timestamp('2023-02-21 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 49,
#   'Tokens Generated': 408},
#  {'Date': Timestamp('2023-02-22 00:00:00'),
#   'Prompt': 'Describe the impact of AI on healthcare',
#   'Response Time (ms)': 90,
#   'Tokens Generated': 416},
#  {'Date': Timestamp('2023-02-23 00:00:00'),
#   'Prompt': 'Generate marketing copy for a new tech product',
#   'Response Time (ms)': 74,
#   'Tokens Generated': 318},
#  {'Date': Timestamp('2023-02-24 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 54,
#   'Tokens Generated': 372},
#  {'Date': Timestamp('2023-02-25 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 86,
#   'Tokens Generated': 461},
#  {'Date': Timestamp('2023-02-26 00:00:00'),
#   'Prompt': 'Summarize the latest research on climate change',
#   'Response Time (ms)': 86,
#   'Tokens Generated': 500},
#  {'Date': Timestamp('2023-02-27 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 85,
#   'Tokens Generated': 203},
#  {'Date': Timestamp('2023-02-28 00:00:00'),
#   'Prompt': 'Create a recipe using plant-based ingredients',
#   'Response Time (ms)': 86,
#   'Tokens Generated': 276},
#  {'Date': Timestamp('2023-03-01 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 90,
#   'Tokens Generated': 223},
#  {'Date': Timestamp('2023-03-02 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 87,
#   'Tokens Generated': 209},
#  {'Date': Timestamp('2023-03-03 00:00:00'),
#   'Prompt': 'Generate marketing copy for a new tech product',
#   'Response Time (ms)': 30,
#   'Tokens Generated': 427},
#  {'Date': Timestamp('2023-03-04 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 42,
#   'Tokens Generated': 219},
#  {'Date': Timestamp('2023-03-05 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 48,
#   'Tokens Generated': 486},
#  {'Date': Timestamp('2023-03-06 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 51,
#   'Tokens Generated': 269},
#  {'Date': Timestamp('2023-03-07 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 38,
#   'Tokens Generated': 342},
#  {'Date': Timestamp('2023-03-08 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 70,
#   'Tokens Generated': 379},
#  {'Date': Timestamp('2023-03-09 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 83,
#   'Tokens Generated': 300},
#  {'Date': Timestamp('2023-03-10 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 59,
#   'Tokens Generated': 316},
#  {'Date': Timestamp('2023-03-11 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 88,
#   'Tokens Generated': 377},
#  {'Date': Timestamp('2023-03-12 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 80,
#   'Tokens Generated': 450},
#  {'Date': Timestamp('2023-03-13 00:00:00'),
#   'Prompt': 'Write a sci-fi short story set in 2050',
#   'Response Time (ms)': 82,
#   'Tokens Generated': 428},
#  {'Date': Timestamp('2023-03-14 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 74,
#   'Tokens Generated': 438},
#  {'Date': Timestamp('2023-03-15 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 91,
#   'Tokens Generated': 293},
#  {'Date': Timestamp('2023-03-16 00:00:00'),
#   'Prompt': 'Create a recipe using plant-based ingredients',
#   'Response Time (ms)': 37,
#   'Tokens Generated': 445},
#  {'Date': Timestamp('2023-03-17 00:00:00'),
#   'Prompt': 'Describe the impact of AI on healthcare',
#   'Response Time (ms)': 83,
#   'Tokens Generated': 208},
#  {'Date': Timestamp('2023-03-18 00:00:00'),
#   'Prompt': 'Generate marketing copy for a new tech product',
#   'Response Time (ms)': 91,
#   'Tokens Generated': 329},
#  {'Date': Timestamp('2023-03-19 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 42,
#   'Tokens Generated': 318},
#  {'Date': Timestamp('2023-03-20 00:00:00'),
#   'Prompt': 'Generate marketing copy for a new tech product',
#   'Response Time (ms)': 94,
#   'Tokens Generated': 286},
#  {'Date': Timestamp('2023-03-21 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 61,
#   'Tokens Generated': 401},
#  {'Date': Timestamp('2023-03-22 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 90,
#   'Tokens Generated': 226},
#  {'Date': Timestamp('2023-03-23 00:00:00'),
#   'Prompt': 'Generate marketing copy for a new tech product',
#   'Response Time (ms)': 37,
#   'Tokens Generated': 453},
#  {'Date': Timestamp('2023-03-24 00:00:00'),
#   'Prompt': 'Create a recipe using plant-based ingredients',
#   'Response Time (ms)': 88,
#   'Tokens Generated': 206},
#  {'Date': Timestamp('2023-03-25 00:00:00'),
#   'Prompt': 'Summarize the latest research on climate change',
#   'Response Time (ms)': 70,
#   'Tokens Generated': 361},
#  {'Date': Timestamp('2023-03-26 00:00:00'),
#   'Prompt': 'Write a sci-fi short story set in 2050',
#   'Response Time (ms)': 89,
#   'Tokens Generated': 255},
#  {'Date': Timestamp('2023-03-27 00:00:00'),
#   'Prompt': 'Outline the ethical considerations of AI',
#   'Response Time (ms)': 79,
#   'Tokens Generated': 276},
#  {'Date': Timestamp('2023-03-28 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 57,
#   'Tokens Generated': 313},
#  {'Date': Timestamp('2023-03-29 00:00:00'),
#   'Prompt': 'Create a recipe using plant-based ingredients',
#   'Response Time (ms)': 43,
#   'Tokens Generated': 400},
#  {'Date': Timestamp('2023-03-30 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 51,
#   'Tokens Generated': 461},
#  {'Date': Timestamp('2023-03-31 00:00:00'),
#   'Prompt': 'Explain blockchain for beginners',
#   'Response Time (ms)': 78,
#   'Tokens Generated': 490},
#  {'Date': Timestamp('2023-04-01 00:00:00'),
#   'Prompt': 'Generate a creative story about space travel',
#   'Response Time (ms)': 71,
#   'Tokens Generated': 482},
#  {'Date': Timestamp('2023-04-02 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 69,
#   'Tokens Generated': 462},
#  {'Date': Timestamp('2023-04-03 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 83,
#   'Tokens Generated': 421},
#  {'Date': Timestamp('2023-04-04 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 97,
#   'Tokens Generated': 325},
#  {'Date': Timestamp('2023-04-05 00:00:00'),
#   'Prompt': 'Summarize the latest research on climate change',
#   'Response Time (ms)': 41,
#   'Tokens Generated': 500},
#  {'Date': Timestamp('2023-04-06 00:00:00'),
#   'Prompt': 'Explain quantum computing in simple terms',
#   'Response Time (ms)': 61,
#   'Tokens Generated': 304},
#  {'Date': Timestamp('2023-04-07 00:00:00'),
#   'Prompt': 'Write a sci-fi short story set in 2050',
#   'Response Time (ms)': 57,
#   'Tokens Generated': 238},
#  {'Date': Timestamp('2023-04-08 00:00:00'),
#   'Prompt': 'Write a poem about the future of technology',
#   'Response Time (ms)': 38,
#   'Tokens Generated': 465},
#  {'Date': Timestamp('2023-04-09 00:00:00'),
#   'Prompt': 'Generate marketing copy for a new tech product',
#   'Response Time (ms)': 77,
#   'Tokens Generated': 296},
#  {'Date': Timestamp('2023-04-10 00:00:00'),
#   'Prompt': 'Create a recipe using plant-based ingredients',
#   'Response Time (ms)': 55,
#   'Tokens Generated': 306}]

# %%
with open('chat_data.yaml', 'w') as file:
    yaml.dump(data_dict, file)
